# %%
from crewai import Agent, Crew, Process, Task
from crewai_tools import PDFSearchTool

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
import openai
os.environ["OPENAI_API_KEY"] = ""

# %%
from crewai import LLM

llm = LLM(
    model = "gemini/gemini-2.5-flash",
    temperature=0.1, 
    api_key="xxxx" 
)

llm.call("Who is Ariana Grande")
# Out:
# 'Ariana Grande-Butera, known professionally as **Ariana Grande**, is an American singer, songwriter, and actress who has become one of the most successful and influential pop artists of her generation.\n\nHere\'s a breakdown of who she is:\n\n1.  **Early Career & Acting:** She first rose to prominence as an actress on the Nickelodeon television series *Victorious* (2010-2013), playing the role of Cat Valentine. She then reprised the role in the spin-off *Sam & Cat* (2013-2014).\n\n2.  **Music Career & Vocal Talent:** While acting gave her a platform, it\'s her powerful vocal talent that truly launched her into superstardom.\n    *   **Vocal Range:** She is renowned for her impressive four-octave vocal range, often utilizing the whistle register, and a distinctive blend of pop, R&B, and hip-hop influences.\n    *   **Albums:** Her discography includes highly successful albums like:\n        *   *Yours Truly* (2013)\n        *   *My Everything* (2014)\n        *   *Dangerous Woman* (2016)\n        *   *Sweetener* (2018)\n        *   *Thank U, Next* (2019)\n        *   *Positions* (2020)\n        *   *Eternal Sunshine* (2024)\n    *   **Hit Singles:** She has numerous chart-topping singles, including "Problem," "Bang Bang," "Side to Side," "No Tears Left to Cry," "God Is a Woman," "Thank U, Next," "7 Rings," and "Positions."\n\n3.  **Awards & Recognition:** Grande has won numerous accolades throughout her career, including multiple Grammy Awards, MTV Video Music Awards, Billboard Women in Music awards, and many others, solidifying her status as a global superstar.\n\n4.  **Cultural Impact & Other Ventures:**\n    *   **Fashion & Influence:** She is also a fashion icon and a prominent voice on social media, with a massive following.\n    *   **Philanthropy:** She is known for her philanthropic efforts and advocacy for various social causes, notably organizing the "One Love Manchester" benefit concert after the 2017 Manchester Arena bombing.\n    *   **Business:** She has a highly successful fragrance line.\n    *   **Return to Acting:** She has continued to act, appearing in films like *Don\'t Look Up* and is set to star as Glinda in the highly anticipated two-part film adaptation of the musical *Wicked*.\n\nIn essence, Ariana Grande is a multi-talented artist celebrated for her extraordinary vocal abilities, consistent chart success, and significant cultural influence across music, fashion, and social media.'

# %%
pdf_search_tool = PDFSearchTool(
    config=dict(
        llm=llm,
        embedder=dict(
            provider="google",
            config=dict(
                model="models/embedding-001",
                task_type="retrieval_document",
            ),
        ),
    ),
    pdf="./example.pdf",
)

# %%
research_agent = Agent(
    role="Research Agent",
    goal="Search through the PDF to find relevant answers",
    allow_delegation=False,
    verbose=True,
    backstory=(
        """
        The research agent is adept at searching and 
        extracting data from documents, ensuring accurate and prompt responses.
        """
    ),
    tools=[pdf_search_tool],

)

# %%
professional_writer_agent = Agent(
    role="Professional Writer",
    goal="Write professional emails based on the research agent's findings",
    allow_delegation=False,
    verbose=True,
    backstory=(
        """
        The professional writer agent has excellent writing skills and is able to craft 
        clear and concise emails based on the provided information.
        """
    ),
    tools=[],
)

# %%
answer_customer_question_task = Task(
    description=(
        """
        Answer the customer's questions based on the home inspection PDF.
        The research agent will search through the PDF to find the relevant answers.
        Your final answer MUST be clear and accurate, based on the content of the PDF.

        Here is the customer's question:
        {customer_question}
        """
    ),
    expected_output="""
        Provide clear and accurate answers to the customer's questions based on 
        the content of the PDF.
        """,
    tools=[pdf_search_tool],
    agent=research_agent,
)

# %%
write_email_task = Task(
    description=(
        """
        - Write a professional email based 
            on the research agent's findings.
        
            Best regards,

           Arpon Sadhukhan
        """
    ),
    expected_output="""
        Write a clear and concise email that can be sent to a recruiter found in report.
        """,
    tools=[],
    agent=professional_writer_agent,
)

# %%
crew = Crew(
    agents=[research_agent, professional_writer_agent],
    tasks=[answer_customer_question_task, write_email_task],
    process=Process.sequential,
)

# %%
customer_question = input(
    "What is the pdf about"
)
result = crew.kickoff(inputs={"customer_question": customer_question})
print(result)
# Out:
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ ðŸ¤– Agent Started â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  Agent: Research Agent                                                                                          â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Task:                                                                                                          â”‚
# â”‚          Answer the customer's questions based on the home inspection PDF.                                      â”‚
# â”‚          The research agent will search through the PDF to find the relevant answers.                           â”‚
# â”‚          Your final answer MUST be clear and accurate, based on the content of the PDF.                         â”‚
# â”‚                                                                                                                 â”‚
# â”‚          Here is the customer's question:                                                                       â”‚
# â”‚          What are Arpon's skills                                                                                â”‚
# â”‚                                                                                                                 â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# I encountered an error while trying to use the tool. This was the error: Arguments validation failed: 1 validation error for FixedPDFSearchToolSchema
# query
#   Input should be a valid string [type=string_type, input_value={'description': "Arpon's skills", 'type': 'str'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type.
#  Tool Search a PDF's content accepts these inputs: Tool Name: Search a PDF's content
# Tool Arguments: {'query': {'description': "Mandatory query you want to use to search the PDF's content", 'type': 'str'}}
# Tool Description: A tool that can be used to semantic search a query the ./example.pdf PDF's content.
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ ðŸ”§ Agent Tool Execution â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  Agent: Research Agent                                                                                          â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Thought: I need to search the PDF for information about Arpon's skills to accurately answer the customer's     â”‚
# â”‚  question.                                                                                                      â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Using Tool: Search a PDF's content                                                                             â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ Tool Input â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  "{\"query\": {\"description\": \"Arpon's skills\", \"type\": \"str\"}}"                                        â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ Tool Output â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚                                                                                                                 â”‚
# â”‚  I encountered an error while trying to use the tool. This was the error: Arguments validation failed: 1        â”‚
# â”‚  validation error for FixedPDFSearchToolSchema                                                                  â”‚
# â”‚  query                                                                                                          â”‚
# â”‚    Input should be a valid string [type=string_type, input_value={'description': "Arpon's skills", 'type':      â”‚
# â”‚  'str'}, input_type=dict]                                                                                       â”‚
# â”‚      For further information visit https://errors.pydantic.dev/2.11/v/string_type.                              â”‚
# â”‚   Tool Search a PDF's content accepts these inputs: Tool Name: Search a PDF's content                           â”‚
# â”‚  Tool Arguments: {'query': {'description': "Mandatory query you want to use to search the PDF's content",       â”‚
# â”‚  'type': 'str'}}                                                                                                â”‚
# â”‚  Tool Description: A tool that can be used to semantic search a query the ./example.pdf PDF's content..         â”‚
# â”‚  Moving on then. I MUST either use a tool (use one at time) OR give my best final answer not both at the same   â”‚
# â”‚  time. When responding, I must use the following format:                                                        â”‚
# â”‚                                                                                                                 â”‚
# â”‚  ```                                                                                                            â”‚
# â”‚  Thought: you should always think about what to do                                                              â”‚
# â”‚  Action: the action to take, should be one of [Search a PDF's content]                                          â”‚
# â”‚  Action Input: the input to the action, dictionary enclosed in curly braces                                     â”‚
# â”‚  Observation: the result of the action                                                                          â”‚
# â”‚  ```                                                                                                            â”‚
# â”‚  This Thought/Action/Action Input/Result can repeat N times. Once I know the final answer, I must return the    â”‚
# â”‚  following format:                                                                                              â”‚
# â”‚                                                                                                                 â”‚
# â”‚  ```                                                                                                            â”‚
# â”‚  Thought: I now can give a great answer                                                                         â”‚
# â”‚  Final Answer: Your final answer must be the great and the most complete as possible, it must be outcome        â”‚
# â”‚  described                                                                                                      â”‚
# â”‚                                                                                                                 â”‚
# â”‚  ```                                                                                                            â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ ðŸ”§ Agent Tool Execution â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  Agent: Research Agent                                                                                          â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Thought: Thought: I need to conduct a search in the PDF for information on Arpon's skills to provide an        â”‚
# â”‚  accurate answer.                                                                                               â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Using Tool: Search a PDF's content                                                                             â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ Tool Input â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  "{\"query\": \"Arpon's skills\"}"                                                                              â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ Tool Output â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  Relevant Content:                                                                                              â”‚
# â”‚  Page 1:                                                                                                        â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Arpon Sadhukhan                                                                                                â”‚
# â”‚                                                                                                                 â”‚
# â”‚  /envelâŒ¢pearpon.skhan@gmail.com | â™‚phone+91 9831911890 | /linkedinarponsadhukhan | /githubLifeHashed            â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Education                                                                                                      â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ National Institute of Technology, Durgapur Nov 2022 â€“ June 2026                                              â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Bachelor of Technology - Computer Engineering; CGPA: 8.16                                                      â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Don Bosco, Bandel Passing Year: 2022                                                                         â”‚
# â”‚                                                                                                                 â”‚
# â”‚  ISC (Class 12); Percentage (Best 4 Sub.): 95.5%                                                                â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Don Bosco, Bandel Passing Year: 2020                                                                         â”‚
# â”‚                                                                                                                 â”‚
# â”‚  ICSE (Class 10); Percentage (Best 5 Sub.): 96.2%                                                               â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Skills Summary                                                                                                 â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Languages: Python, C, C++, C, Java, JavaScript, SQL                                                          â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Frameworks:                                                                                                  â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€“ ML/DL:Pandas, NumPy, Scikit-learn, Matplotlib, Seaborn, TensorFlow, Keras, Hugging Face Transformers,        â”‚
# â”‚  OpenCV,                                                                                                        â”‚
# â”‚                                                                                                                 â”‚
# â”‚  NLP, ANN, RNN, LSTM, Attention Mechanisms, BERT, spaCy                                                         â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€“ Development: Flask, Fast API, ReactJS, Tailwind CSS, Electron JS                                             â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Toolkit: Git, PostgreSQL, MongoDB, Firebase, Redis, Docker, Kubernetes, Streamlit dashboards, Excel          â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Platforms: Jupyter Notebook, VS Code, IntelliJ, LINUX, Android Studio, Microsoft Azure, Oracle Cloud         â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Soft Skills:Leadership, Team Work, Public Speaking, Time Management, Critical Thinking and Reasoning         â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Interests: Machine Learning, Deep Learning, Web & App Development, Data Structures and Algorithms,           â”‚
# â”‚  Statistics,                                                                                                    â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Business Analytics                                                                                             â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Projects                                                                                                       â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Redact-X | LINK: SIH 2024 Finals project. Built an offline redaction tool to mask PII in various file        â”‚
# â”‚  formats using                                                                                                  â”‚
# â”‚                                                                                                                 â”‚
# â”‚  RoBERTa, BERT, spaCy, and regex. Fine-tuned models on 10M+ records for secure on-device processing.            â”‚
# â”‚                                                                                                                 â”‚
# â”‚                                                                                                                 â”‚
# â”‚  RoBERTa, BERT, spaCy, and regex. Fine-tuned models on 10M+ records for secure on-device processing.            â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ Impruv.com | LINK: Freelanced for Production-Ready UPSC preparation website with evaluartion features for    â”‚
# â”‚  descrip-                                                                                                       â”‚
# â”‚                                                                                                                 â”‚
# â”‚  tive answers and an unique credit based system for users and evualuators.                                      â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Experience                                                                                                     â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€¢ SWE Internship: Microsoft Corporation May 2025 â€“ July 2025                                                   â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Under Naveen Kurmadas, Principal Software Engineering Manager at Azure Specialized.                            â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€“ Worked on Azure Monitor for SAP solution.                                                                    â”‚
# â”‚                                                                                                                 â”‚
# â”‚  â€“ created a common library for emitting...                                                                     â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ âœ… Agent Final Answer â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  Agent: Research Agent                                                                                          â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Final Answer:                                                                                                  â”‚
# â”‚  Arpon's skills include:                                                                                        â”‚
# â”‚                                                                                                                 â”‚
# â”‚  - **Languages**: Python, C, C++, Java, JavaScript, SQL                                                         â”‚
# â”‚                                                                                                                 â”‚
# â”‚  - **Frameworks**:                                                                                              â”‚
# â”‚    - **Machine Learning/Deep Learning**: Pandas, NumPy, Scikit-learn, Matplotlib, Seaborn, TensorFlow, Keras,   â”‚
# â”‚  Hugging Face Transformers, OpenCV, NLP, ANN, RNN, LSTM, Attention Mechanisms, BERT, spaCy                      â”‚
# â”‚    - **Development**: Flask, Fast API, ReactJS, Tailwind CSS, Electron JS                                       â”‚
# â”‚                                                                                                                 â”‚
# â”‚  - **Toolkit**: Git, PostgreSQL, MongoDB, Firebase, Redis, Docker, Kubernetes, Streamlit dashboards, Excel      â”‚
# â”‚                                                                                                                 â”‚
# â”‚  - **Platforms**: Jupyter Notebook, VS Code, IntelliJ, LINUX, Android Studio, Microsoft Azure, Oracle Cloud     â”‚
# â”‚                                                                                                                 â”‚
# â”‚  - **Soft Skills**: Leadership, Team Work, Public Speaking, Time Management, Critical Thinking, and Reasoning   â”‚
# â”‚                                                                                                                 â”‚
# â”‚  - **Interests**: Machine Learning, Deep Learning, Web & App Development, Data Structures and Algorithms,       â”‚
# â”‚  Statistics, Business Analytics                                                                                 â”‚
# â”‚                                                                                                                 â”‚
# â”‚  This summarizes Arpon's extensive skill set across various programming languages, frameworks, tools, and soft  â”‚
# â”‚  skills.                                                                                                        â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ ðŸ¤– Agent Started â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  Agent: Professional Writer                                                                                     â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Task:                                                                                                          â”‚
# â”‚          - Write a professional email based                                                                     â”‚
# â”‚              on the research agent's findings.                                                                  â”‚
# â”‚                                                                                                                 â”‚
# â”‚              Best regards,                                                                                      â”‚
# â”‚                                                                                                                 â”‚
# â”‚             Arpon Sadhukhan                                                                                     â”‚
# â”‚                                                                                                                 â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# â•­â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ âœ… Agent Final Answer â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•®
# â”‚                                                                                                                 â”‚
# â”‚  Agent: Professional Writer                                                                                     â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Final Answer:                                                                                                  â”‚
# â”‚  Subject: Application for [Job Title] Position                                                                  â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Dear [Recruiterâ€™s Name],                                                                                       â”‚
# â”‚                                                                                                                 â”‚
# â”‚  I hope this message finds you well. My name is Arpon Sadhukhan, and I am reaching out to express my interest   â”‚
# â”‚  in the [Job Title] position at [Company Name], as advertised on [where you found the job posting].             â”‚
# â”‚                                                                                                                 â”‚
# â”‚  I possess a strong background in programming languages such as Python, C, C++, Java, JavaScript, and SQL. My   â”‚
# â”‚  expertise extends to machine learning and deep learning frameworks, including Pandas, NumPy, Scikit-learn,     â”‚
# â”‚  TensorFlow, and Keras, among others. In addition, I am proficient in web and app development frameworks such   â”‚
# â”‚  as Flask, Fast API, and ReactJS.                                                                               â”‚
# â”‚                                                                                                                 â”‚
# â”‚  My technical toolkit includes Git, PostgreSQL, MongoDB, and Docker, which I have effectively utilized in       â”‚
# â”‚  previous projects. I am also skilled in using platforms like Jupyter Notebook and Microsoft Azure to deliver   â”‚
# â”‚  data-driven solutions.                                                                                         â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Beyond my technical capabilities, I pride myself on my soft skills, including leadership, teamwork, and        â”‚
# â”‚  critical thinking. I am passionate about continuous learning and am eager to contribute to innovative          â”‚
# â”‚  projects in machine learning, web development, and business analytics.                                         â”‚
# â”‚                                                                                                                 â”‚
# â”‚  I have attached my resume for your review and would appreciate the opportunity to discuss how my skills and    â”‚
# â”‚  experiences align with the needs of your team. I am looking forward to the possibility of discussing this      â”‚
# â”‚  exciting opportunity with you.                                                                                 â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Thank you for considering my application.                                                                      â”‚
# â”‚                                                                                                                 â”‚
# â”‚  Best regards,                                                                                                  â”‚
# â”‚  Arpon Sadhukhan                                                                                                â”‚
# â”‚  [Your LinkedIn Profile]                                                                                        â”‚
# â”‚  [Your Phone Number]                                                                                            â”‚
# â”‚  [Your Email Address]                                                                                           â”‚
# â”‚                                                                                                                 â”‚
# â•°â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â•¯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Subject: Application for [Job Title] Position
#
# Dear [Recruiterâ€™s Name],
#
# I hope this message finds you well. My name is Arpon Sadhukhan, and I am reaching out to express my interest in the [Job Title] position at [Company Name], as advertised on [where you found the job posting].
#
# I possess a strong background in programming languages such as Python, C, C++, Java, JavaScript, and SQL. My expertise extends to machine learning and deep learning frameworks, including Pandas, NumPy, Scikit-learn, TensorFlow, and Keras, among others. In addition, I am proficient in web and app development frameworks such as Flask, Fast API, and ReactJS.
#
# My technical toolkit includes Git, PostgreSQL, MongoDB, and Docker, which I have effectively utilized in previous projects. I am also skilled in using platforms like Jupyter Notebook and Microsoft Azure to deliver data-driven solutions.
#
# Beyond my technical capabilities, I pride myself on my soft skills, including leadership, teamwork, and critical thinking. I am passionate about continuous learning and am eager to contribute to innovative projects in machine learning, web development, and business analytics.
#
# I have attached my resume for your review and would appreciate the opportunity to discuss how my skills and experiences align with the needs of your team. I am looking forward to the possibility of discussing this exciting opportunity with you.
#
# Thank you for considering my application.
#
# Best regards,
# Arpon Sadhukhan
# [Your LinkedIn Profile]
# [Your Phone Number]
# [Your Email Address]
